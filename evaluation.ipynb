# %% [markdown]
# # Evaluation of Voice-to-Voice Multi-Agent Product Assistant
#
# This notebook evaluates our LangGraph-based, multi-agent product recommender.
#
# We measure:
#
# - **ROUGE-L**: similarity of answers to reference responses
# - **BLEU**: n-gram precision vs reference
# - **Precision@K**: relevance of top-K retrieved products (optional, needs labels)
# - **Latency (cold vs warm cache)**: end-to-end response time
# - **Cost (optional)**: approximate $-cost per query based on tokens
#
# > **Important**: Before running this notebook, make sure the MCP server is running.

# %%
# !pip install rouge-score nltk requests
# Out:
# Collecting rouge-score
#   Downloading rouge_score-0.1.2.tar.gz (17 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting nltk
#   Downloading nltk-3.9.2-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: requests in c:\users\19546\anaconda3\envs\pythonproject\lib\site-packages (2.32.5)
# Requirement already satisfied: absl-py in c:\users\19546\anaconda3\envs\pythonproject\lib\site-packages (from rouge-score) (2.1.0)
# Requirement already satisfied: numpy in c:\users\19546\anaconda3\envs\pythonproject\lib\site-packages (from rouge-score) (1.26.4)
# Requirement already satisfied: six>=1.14.0 in c:\users\19546\anaconda3\envs\pythonproject\lib\site-packages (from rouge-score) (1.17.0)
# Requirement already satisfied: click in c:\users\19546\anaconda3\envs\pythonproject\lib\site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in c:\users\19546\anaconda3\envs\pythonproject\lib\site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\19546\anaconda3\envs\pythonproject\lib\site-packages (from nltk) (2025.11.3)
# Requirement already satisfied: tqdm in c:\users\19546\anaconda3\envs\pythonproject\lib\site-packages (from nltk) (4.67.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\19546\anaconda3\envs\pythonproject\lib\site-packages (from requests) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\19546\anaconda3\envs\pythonproject\lib\site-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\19546\anaconda3\envs\pythonproject\lib\site-packages (from requests) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\19546\anaconda3\envs\pythonproject\lib\site-packages (from requests) (2025.11.12)
# Requirement already satisfied: colorama in c:\users\19546\anaconda3\envs\pythonproject\lib\site-packages (from click->nltk) (0.4.6)
# Downloading nltk-3.9.2-py3-none-any.whl (1.5 MB)
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ------ --------------------------------- 0.3/1.5 MB ? eta -:--:--
#    ------ --------------------------------- 0.3/1.5 MB ? eta -:--:--
#    ------ --------------------------------- 0.3/1.5 MB ? eta -:--:--
#    ------------- -------------------------- 0.5/1.5 MB 372.9 kB/s eta 0:00:03
#    ------------- -------------------------- 0.5/1.5 MB 372.9 kB/s eta 0:00:03
#    ------------- -------------------------- 0.5/1.5 MB 372.9 kB/s eta 0:00:03
#    ------------- -------------------------- 0.5/1.5 MB 372.9 kB/s eta 0:00:03
#    ------------- -------------------------- 0.5/1.5 MB 372.9 kB/s eta 0:00:03
#    ------------- -------------------------- 0.5/1.5 MB 372.9 kB/s eta 0:00:03
#    ------------- -------------------------- 0.5/1.5 MB 372.9 kB/s eta 0:00:03
#    -------------------- ------------------- 0.8/1.5 MB 233.0 kB/s eta 0:00:04
#    -------------------- ------------------- 0.8/1.5 MB 233.0 kB/s eta 0:00:04
#    -------------------- ------------------- 0.8/1.5 MB 233.0 kB/s eta 0:00:04
#    -------------------- ------------------- 0.8/1.5 MB 233.0 kB/s eta 0:00:04
#    -------------------- ------------------- 0.8/1.5 MB 233.0 kB/s eta 0:00:04
#    -------------------- ------------------- 0.8/1.5 MB 233.0 kB/s eta 0:00:04
#    -------------------- ------------------- 0.8/1.5 MB 233.0 kB/s eta 0:00:04
#    -------------------- ------------------- 0.8/1.5 MB 233.0 kB/s eta 0:00:04
#    -------------------- ------------------- 0.8/1.5 MB 233.0 kB/s eta 0:00:04
#    --------------------------- ------------ 1.0/1.5 MB 192.1 kB/s eta 0:00:03
#    --------------------------- ------------ 1.0/1.5 MB 192.1 kB/s eta 0:00:03
#    --------------------------- ------------ 1.0/1.5 MB 192.1 kB/s eta 0:00:03
#    --------------------------- ------------ 1.0/1.5 MB 192.1 kB/s eta 0:00:03
#    --------------------------- ------------ 1.0/1.5 MB 192.1 kB/s eta 0:00:03
#    ---------------------------------- ----- 1.3/1.5 MB 202.2 kB/s eta 0:00:02
#    ---------------------------------- ----- 1.3/1.5 MB 202.2 kB/s eta 0:00:02
#    ---------------------------------- ----- 1.3/1.5 MB 202.2 kB/s eta 0:00:02
#    ---------------------------------- ----- 1.3/1.5 MB 202.2 kB/s eta 0:00:02
#    ---------------------------------- ----- 1.3/1.5 MB 202.2 kB/s eta 0:00:02
#    ---------------------------------- ----- 1.3/1.5 MB 202.2 kB/s eta 0:00:02
#    ---------------------------------- ----- 1.3/1.5 MB 202.2 kB/s eta 0:00:02
#    ---------------------------------- ----- 1.3/1.5 MB 202.2 kB/s eta 0:00:02
#    ---------------------------------- ----- 1.3/1.5 MB 202.2 kB/s eta 0:00:02
#    ---------------------------------- ----- 1.3/1.5 MB 202.2 kB/s eta 0:00:02
#    ---------------------------------- ----- 1.3/1.5 MB 202.2 kB/s eta 0:00:02
#    ---------------------------------- ----- 1.3/1.5 MB 202.2 kB/s eta 0:00:02
#    ---------------------------------- ----- 1.3/1.5 MB 202.2 kB/s eta 0:00:02
#    ---------------------------------------- 1.5/1.5 MB 156.1 kB/s eta 0:00:00
# Building wheels for collected packages: rouge-score
#   Building wheel for rouge-score (setup.py): started
#   Building wheel for rouge-score (setup.py): finished with status 'done'
#   Created wheel for rouge-score: filename=rouge_score-0.1.2-py3-none-any.whl size=24972 sha256=4690ddbff43fae54feee38266e772d9329718f5cf4e51eff7f0fe37acd3ff33e
#   Stored in directory: c:\users\19546\appdata\local\pip\cache\wheels\5f\dd\89\461065a73be61a532ff8599a28e9beef17985c9e9c31e541b4
# Successfully built rouge-score
# Installing collected packages: nltk, rouge-score
# Successfully installed nltk-3.9.2 rouge-score-0.1.2

# %%
import sys
import time
import statistics
from typing import List, Dict, Any, Optional

sys.path.append(".")

import requests
from src.agents.graph import invoke_with_logging
from src.mcp_server.config import config

# Optional metrics
try:
    from rouge_score import rouge_scorer
except ImportError:
    rouge_scorer = None
    print("⚠️ rouge-score not installed, ROUGE-L will be skipped. Install with: pip install rouge-score")

try:
    from nltk.translate.bleu_score import sentence_bleu, SmoothingFunction
except ImportError:
    sentence_bleu = None
    SmoothingFunction = None
    print("⚠️ nltk not installed, BLEU will be skipped. Install with: pip install nltk")

# %%
"""
set OPENAI_API_KEY and SERPAPI_KEY
"""

import os
from getpass import getpass
from dotenv import load_dotenv, find_dotenv

# Optional: Load .env file automatically if it exists
# This saves you from typing keys if you have a .env file locally
# _ = load_dotenv(find_dotenv())

def check_and_set_key(var_name, display_name):
    """
    Checks if an environment variable exists.
    If not, prompts the user to input it securely (input will be hidden).
    """
    # 1. Try to get the variable from the environment
    key = os.getenv(var_name)

    # 2. If not found, prompt the user
    if not key:
        print(f"⚠️ {var_name} not found in environment.")
        # getpass hides your keystrokes for security
        key_input = getpass(f"👉 Please enter your {display_name}: ").strip()

        if not key_input:
            print(f"❌ Error: You did not enter {display_name}. The program may not function correctly.")
            return None

        # 3. Set the variable in the current session
        os.environ[var_name] = key_input
        print(f"✅ {var_name} has been set manually!")
    else:
        # If found (e.g., loaded from .env)
        # Show first 5 chars for verification, hide the rest
        print(f"✅ {var_name} is already set (Value: {key[:5]}...).")

# --- Execute Checks ---

# 1. Check OpenAI API Key
check_and_set_key("OPENAI_API_KEY", "OpenAI API Key")

print("-" * 30)

# 2. Check SerpApi Key
# Note: Ensure this variable name matches what your code expects (e.g. SERPAPI_KEY or SERPAPI_API_KEY)
check_and_set_key("SERPAPI_KEY", "SerpApi Key")
# Out:
# ⚠️ OPENAI_API_KEY not found in environment.
# ✅ OPENAI_API_KEY has been set manually!
# ------------------------------
# ⚠️ SERPAPI_KEY not found in environment.
# ✅ SERPAPI_KEY has been set manually!

# %%
import chromadb
import pandas as pd

CHROMA_PATH = "vectordb/chroma"

client = chromadb.PersistentClient(path=CHROMA_PATH)
collection = client.get_collection(name="products")

# Query ALL metadata by setting n_results = large number
raw = collection.get(include=["metadatas", "documents"])

len(raw["ids"]), len(raw["metadatas"]), len(raw["documents"])
# Out:
# (8661, 8661, 8661)

# %%
def chroma_to_dataframe(raw):
    df = pd.DataFrame({
        "doc_id": raw["ids"],
        "document": raw["documents"],
        "metadata": raw["metadatas"]
    })

    # Expand metadata (metadata is a dict)
    meta_df = pd.json_normalize(df["metadata"])
    df = df.drop(columns=["metadata"]).join(meta_df)
    return df

df_products = chroma_to_dataframe(raw)
df_products.head()
# Out:
#       doc_id                                           document price_bucket  \
# 0  doc_00000  DB Longboards CoreFlex Crossbow 41" Bamboo Fib...      premium
# 1  doc_00001  Electronic Snap Circuits Mini Kits Classpack, ...      premium
# 2  doc_00002  3Doodler Create Flexy 3D Printing Filament Ref...          mid
# 3  doc_00003  Guillow Airplane Design Studio with Travel Cas...          mid
# 4  doc_00004  Woodstock- Collage 500 pc Puzzle | Puzzle has ...          mid
#
#     price sub_category                                        product_url  \
# 0  237.68            &  https://www.amazon.com/DB-Longboards-CoreFlex-...
# 1   99.95            &  https://www.amazon.com/Electronic-Circuits-Cla...
# 2   34.99            &  https://www.amazon.com/3Doodler-Plastic-Innova...
# 3   28.91            &  https://www.amazon.com/Guillow-Airplane-Design...
# 4   17.49            &  https://www.amazon.com/Woodstock-Collage-500-p...
#
#    eco_friendly                                              title  \
# 0         False  DB Longboards CoreFlex Crossbow 41" Bamboo Fib...
# 1         False  Electronic Snap Circuits Mini Kits Classpack, ...
# 2          True  3Doodler Create Flexy 3D Printing Filament Ref...
# 3         False  Guillow Airplane Design Studio with Travel Cas...
# 4         False                   Woodstock- Collage 500 pc Puzzle
#
#         brand                                          image_url  \
# 0          DB  https://images-na.ssl-images-amazon.com/images...
# 1  Electronic  https://images-na.ssl-images-amazon.com/images...
# 2    3Doodler  https://images-na.ssl-images-amazon.com/images...
# 3     Guillow  https://images-na.ssl-images-amazon.com/images...
# 4  Woodstock-  https://images-na.ssl-images-amazon.com/images...
#
#                          product_id  has_material main_category
# 0  4c69b61db1fc16e7013b43fc926e502d          True        Sports
# 1  66d49bbed043f5be260fa9f7fbff5957         False          Toys
# 2  2c55cae269aebf53838484b0d7dd931a          True          Toys
# 3  18018b6bc416dab347b1b7db79994afa          True          Toys
# 4  e04b990e95bf73bbe6a3fa09785d7cd0          True          Toys

# %%
df_products.columns
# Out:
# Index(['doc_id', 'document', 'price_bucket', 'price', 'sub_category',
#        'product_url', 'eco_friendly', 'title', 'brand', 'image_url',
#        'product_id', 'has_material', 'main_category'],
#       dtype='object')

# %%
# Evaluation dataset: 10 realistic voice-style queries
# Each item has:
#   - query: user question
#   - reference: ideal answer written by us (for ROUGE/BLEU)
#   - relevant_ids: (optional) list of correct product doc_ids for Precision@K

EVAL_SET: List[Dict[str, Any]] = [
    {
        "id": "q1",
        "query": "Find me a wooden puzzle for kids under $20",
        "reference": (
            "Here is a wooden puzzle for kids under $20 from our catalog, "
            "with good reviews and a safe, child-friendly design."
        ),
        "relevant_ids": [],
    },
    {
        "id": "q2",
        "query": "I need a stainless steel cleaner that’s eco-friendly and under $15",
        "reference": (
            "Here is an eco-friendly stainless steel cleaner under $15, "
            "made with non-toxic ingredients and good customer ratings."
        ),
        "relevant_ids": [],
    },
    {
        "id": "q3",
        "query": "Show me eco-friendly toys under $15 for a 4 year old",
        "reference": (
            "Here are eco-friendly toys under $15 suitable for a 4 year old, "
            "all made from sustainable materials and within your budget."
        ),
        "relevant_ids": [],
    },
    {
        "id": "q4",
        "query": "Recommend a reusable stainless steel water bottle 32 ounce under $25",
        "reference": (
            "Here is a reusable 32 ounce stainless steel water bottle under $25 "
            "with good insulation and strong customer reviews."
        ),
        "relevant_ids": [],
    },
    {
        "id": "q5",
        "query": "Lunch box under $30",
        "reference": (
            "Here is a durable and insulated lunch box under $30 with a leak-proof design, "
            "featuring multiple compartments and excellent ratings for keeping food fresh."
        ),
        "relevant_ids": [],
    },
    {
        "id": "q6",
        "query": "I want a LEGO building set for kids around $30",
        "reference": (
            "Here is a LEGO building set for kids around $30 from our catalog, "
            "with age-appropriate difficulty and good ratings."
        ),
        "relevant_ids": [],
    },
    {
        "id": "q7",
        "query": "Show me a non-stick frying pan under $40 that works on induction",
        "reference": (
            "Here is a non-stick frying pan under $40 that works on induction cooktops, "
            "with durable coating and positive reviews."
        ),
        "relevant_ids": [],
    },
    {
        "id": "q8",
        "query": "Skateboard under $60",
        "reference": (
            "Here is a durable skateboard under $60 suitable for beginners, "
            "featuring a sturdy maple deck and smooth customer reviews."
        ),
        "relevant_ids": [],
    },
    {
        "id": "q9",
        "query": "Party decorations under $100",
        "reference": (
            "Here is a complete party decoration set under $100 that includes "
            "balloons, banners, and tableware, perfect for various events and well reviewed."
        ),
        "relevant_ids": [],
    },
    {
        "id": "q10",
        "query": "I need an ergonomic office chair under $250",
        "reference": (
            "Here is an ergonomic office chair under $250 with adjustable lumbar support "
            "and good long-session comfort reviews."
        ),
        "relevant_ids": [],
    },
]

K = 5  # For Precision@K
len(EVAL_SET)
# Out:
# 10

# %%
"""
Rule-based “relevant_ids” functions
"""

def get_doc_ids(mask, top_n=5):
    """Helper: from a boolean mask on df_products, return top_n doc_id strings."""
    return df_products[mask].head(top_n)["doc_id"].astype(str).tolist()


def relevant_ids_q1():
    # "Find me a wooden puzzle for kids under $20"
    mask = df_products["title"].str.contains("puzzle", case=False, na=False)
    mask &= df_products["price"] <= 20
    # Optional: restrict to toys if category exists
    if "main_category" in df_products.columns:
        mask &= df_products["main_category"].str.contains("toy", case=False, na=False)
    return get_doc_ids(mask)


def relevant_ids_q2():
    # "stainless steel cleaner eco-friendly under $15"
    # mask = df_products["title"].str.contains("stainless", case=False, na=False)
    # mask &= df_products["title"].str.contains("clean", case=False, na=False)
    mask = df_products["title"].str.contains("clean", case=False, na=False)
    mask &= df_products["price"] <= 15
    # if "eco_friendly" in df_products.columns:
    #     mask &= df_products["eco_friendly"] == True
    return get_doc_ids(mask)


def relevant_ids_q3():
    # "eco-friendly toys under $15 for a 4 year old"
    mask = df_products["price"] <= 15
    if "main_category" in df_products.columns:
        mask &= df_products["main_category"].str.contains("toy", case=False, na=False)
    if "eco_friendly" in df_products.columns:
        mask &= df_products["eco_friendly"] == True
    return get_doc_ids(mask)


def relevant_ids_q4():
    # "reusable stainless steel water bottle 32 ounce under $25"
    mask = df_products["title"].str.contains("bottle", case=False, na=False)
    # mask &= df_products["title"].str.contains("stainless", case=False, na=False)
    # Try to capture 32oz text in title if possible
    mask &= df_products["price"] <= 25
    return get_doc_ids(mask)


def relevant_ids_q5():
    # "lunch box under $30"
    mask = df_products["title"].str.contains("lunch box", case=False, na=False)
    mask &= df_products["price"] <= 30
    # if "eco_friendly" in df_products.columns:
    #     mask &= df_products["eco_friendly"] == True
    return get_doc_ids(mask)


def relevant_ids_q6():
    # "LEGO building set around $30"
    mask = df_products["price"].between(20, 40)  # "around 30"
    if "brand" in df_products.columns:
        mask &= df_products["brand"].str.contains("lego", case=False, na=False)
    else:
        mask &= df_products["title"].str.contains("lego", case=False, na=False)
    return get_doc_ids(mask)


def relevant_ids_q7():
    # "non-stick frying pan under $40 that works on induction"
    mask = df_products["title"].str.contains("pan", case=False, na=False)
    # mask &= df_products["title"].str.contains("non[- ]?stick", case=False, na=False) | \
    #         df_products["title"].str.contains("nonstick", case=False, na=False)
    mask &= df_products["price"] <= 40
    return get_doc_ids(mask)


def relevant_ids_q8():
    # "skateboard under $60"
    mask = df_products["title"].str.contains("skateboard", case=False, na=False)
    mask &= df_products["price"] <= 60
    return get_doc_ids(mask)


def relevant_ids_q9():
    # "party decorations under $100"
    mask = df_products["title"].str.contains("party", case=False, na=False) | \
           df_products["title"].str.contains("decorations", case=False, na=False)
    mask &= df_products["price"] <= 100
    return get_doc_ids(mask)


def relevant_ids_q10():
    # "ergonomic office chair under $250"
    mask = df_products["title"].str.contains("chair", case=False, na=False)
    # mask &= df_products["title"].str.contains("office", case=False, na=False) | \
    #         df_products["title"].str.contains("ergonomic", case=False, na=False)
    mask &= df_products["price"] <= 250
    return get_doc_ids(mask)

# %%
def populate_relevant_ids(eval_set):
    """Fill relevant_ids in-place for queries where we defined rules."""
    mapping = {
        "q1": relevant_ids_q1,
        "q2": relevant_ids_q2,
        "q3": relevant_ids_q3,
        "q4": relevant_ids_q4,
        "q5": relevant_ids_q5,
        "q6": relevant_ids_q6,
        "q7": relevant_ids_q7,
        "q8": relevant_ids_q8,
        "q9": relevant_ids_q9,
        "q10": relevant_ids_q10,
    }

    for item in eval_set:
        fn = mapping.get(item["id"])
        if fn is not None:
            item["relevant_ids"] = fn()
    return eval_set

EVAL_SET = populate_relevant_ids(EVAL_SET)

# Quick check:
[(e["id"], len(e["relevant_ids"])) for e in EVAL_SET]
# Out:
# [('q1', 5),
#  ('q2', 5),
#  ('q3', 5),
#  ('q4', 5),
#  ('q5', 5),
#  ('q6', 5),
#  ('q7', 5),
#  ('q8', 5),
#  ('q9', 5),
#  ('q10', 5)]

# %%
def compute_rouge_l(reference: str, hypothesis: str) -> Optional[float]:
    """Compute ROUGE-L F1 using rouge_score if available."""
    if rouge_scorer is None:
        return None
    scorer = rouge_scorer.RougeScorer(["rougeL"], use_stemmer=True)
    scores = scorer.score(reference, hypothesis)
    return scores["rougeL"].fmeasure


def compute_bleu(reference: str, hypothesis: str) -> Optional[float]:
    """Compute sentence-level BLEU score if nltk is available."""
    if sentence_bleu is None:
        return None
    ref_tokens = reference.split()
    hyp_tokens = hypothesis.split()
    smoothie = SmoothingFunction().method4 if SmoothingFunction else None
    return sentence_bleu([ref_tokens], hyp_tokens, smoothing_function=smoothie)


def precision_at_k(pred_ids: List[str], true_ids: List[str], k: int) -> Optional[float]:
    """
    Precision@K = (# relevant in top-k) / k.
    If no labels are provided, returns None.
    """
    if not true_ids:
        return None
    top_k = pred_ids[:k]
    if not top_k:
        return 0.0
    hits = sum(1 for pid in top_k if pid in true_ids)
    return hits / min(k, len(top_k))

# %%
# def clear_mcp_cache() -> None:
#     """Call MCP /clear_cache to reset RAG + web caches."""
#     url = f"http://{config.MCP_HOST}:{config.MCP_PORT}/clear_cache"
#     try:
#         resp = requests.post(url, timeout=5)
#         if resp.status_code == 200:
#             print("[CACHE] Cleared MCP cache")
#         else:
#             print(f"[CACHE] Failed to clear cache: HTTP {resp.status_code}")
#     except Exception as e:
#         print(f"[CACHE] Error calling clear_cache: {e}")

def clear_mcp_cache():
    """
    Clear RAG + web caches ONLY inside this notebook session.
    Does NOT touch files, embeddings, or the Chroma DB.
    Safe to run repeatedly.
    """
    try:
        from src.mcp_server.utils.cache import rag_cache, web_cache
        rag_cache.clear()
        web_cache.clear()
        print("[CACHE] Cleared rag_cache and web_cache")
    except Exception as e:
        print("[CACHE] Could not clear caches:", e)



def extract_retrieved_ids(result: Dict[str, Any]) -> List[str]:
    """
    Extract product IDs from the graph result for Precision@K.

    This is a generic version. After running one query and printing `result`,
    you should adapt this function to match your actual structure.
    """
    ids: List[str] = []

    # Case 1: products stored directly
    if "retrieved_products" in result:
        for p in result["retrieved_products"]:
            if isinstance(p, dict):
                pid = p.get("doc_id") or p.get("product_id") or p.get("id")
                if pid:
                    ids.append(str(pid))

    # Case 2: product info inside citations
    if not ids and "citations" in result:
        for c in result["citations"]:
            if isinstance(c, dict):
                pid = c.get("doc_id") or c.get("product_id") or c.get("id")
                if pid:
                    ids.append(str(pid))

    return ids


def estimate_cost(execution_stats: Dict[str, Any]) -> Optional[float]:
    """
    Rough cost estimation based on token usage, if logged by your logger.

    Example expected keys:
        execution_stats["total_input_tokens"]
        execution_stats["total_output_tokens"]
    """
    input_tokens = execution_stats.get("total_input_tokens")
    output_tokens = execution_stats.get("total_output_tokens")

    if input_tokens is None or output_tokens is None:
        return None

    total_tokens = input_tokens + output_tokens

    # Example price: $0.002 per 1K tokens, adjust to your real model/pricing
    price_per_1k = 0.002
    cost = (total_tokens / 1000.0) * price_per_1k
    return cost

# %%
sample_query = EVAL_SET[0]["query"]
print("Sample query:", sample_query)

clear_mcp_cache()
result_debug = invoke_with_logging(sample_query)

result_debug.keys()
# Out:
# Sample query: Find me a wooden puzzle for kids under $20
# [CACHE] Cleared rag_cache and web_cache
#
# [ROUTER] Extracted intent: {'product_type': 'puzzle', 'budget': None, 'price_min': None, 'price_max': 20.0, 'category': 'Toys', 'eco_friendly': None, 'materials': ['wood'], 'age_range': 'kids', 'brand': None}
#
# [SAFETY] Is safe: True
#
# [PLANNER] Plan: Search 2020 catalog, then verify current web prices for comparison
# [PLANNER] Tools: ['rag.search', 'web.search']
# [PLANNER] RAG params: {'query': 'wooden kids puzzle', 'price_min': None, 'price_max': 20.0, 'category': 'Toys', 'eco_friendly': None, 'top_k': 5}
#
# [EXECUTOR] Calling rag.search...
# [EXECUTOR] RAG found: 5 products
#
# [EXECUTOR] Calling web.search (Google Shopping via MCP)...
# [EXECUTOR] Price filter: under $20.0
# [EXECUTOR] Running 5 price checks in PARALLEL...
# [EXECUTOR] ✓ Dragon Boat... → 40 results
# [EXECUTOR] ✓ Melissa & Doug Barnyard Wooden Jigsaw Pu... → 40 results
# [EXECUTOR] ✓ Melissa & Doug Personalized Vehicles Woo... → 40 results
# [EXECUTOR] ✓ The Learning Journey My First Big Floor ... → 11 results
# [EXECUTOR] ✓ Mudpuppy 4-Layer Transportation Friends ... → 9 results
# [EXECUTOR] Parallel checks done in 28861ms
# [EXECUTOR] Searching alternatives: 'find me a wooden puzzle for kids under $20'...
# [EXECUTOR] Found 40 alternatives
# [EXECUTOR] Price filter: 180 → 126 results ($0-$20.0)
# [EXECUTOR] Total: 126 web results
#
# [RECONCILER] Starting reconciliation...
# [RECONCILER] RAG results: 5, Web results: 126
# [RECONCILER] Matched 4 products
# [RECONCILER] Found 4 conflicts
# [RECONCILER] Created comparison table with 127 entries
# [RECONCILER] Example match: 'Melissa & Doug Barnyard Wooden Jigsaw Puzzle (24 p...' <-> 'Melissa & Doug African Plains Jigsaw Puzzle...' (score: 0.892)
# [RECONCILER] Example conflict: Catalog shows $7.99, web shows $13.99 (75.1% difference)
#
# [SYNTHESIZER] Generated answer with 5 unique citations
# [SYNTHESIZER] Total citations (with 10 unique web sources): 15
#
# [TTS DEBUG] has_catalog_items: True, has_web_only_items: False
# [TTS DEBUG] Products for voice:
# 1. Melissa & Doug Barnyard Wooden Jigsaw Puzzle (24 pcs) at $7.99 from our catalog, currently $13.99 at Melissa & Doug
# 2. Dragon Boat at $12.99 from our catalog, currently $0.50 at Millennium Games
# 3. Mudpuppy 4-Layer Transportation Friends 12Piece Wood Jigsaw Puzzle, Ages 2+ - Colorful Vehicle Illustrations, Multicolor at $17.99 from our catalog, currently $11.99 at Mudpuppy
# dict_keys(['user_query', 'intent', 'is_safe', 'safety_reason', 'plan', 'tools_to_call', 'rag_params', 'rag_results', 'web_results', 'matched_products', 'conflicts', 'comparison_table', 'final_answer', 'citations', 'tts_summary', '_logging'])

# %%
def run_eval(cold_cache: bool = True) -> Dict[str, Any]:
    """
    Run evaluation over EVAL_SET.

    cold_cache=True:
        clear MCP cache before each query (simulates worst-case latency).
    cold_cache=False:
        keep cache warm across queries.
    """
    run_type = "COLD" if cold_cache else "WARM"
    print(f"\n===== EVALUATION RUN ({run_type} CACHE) =====\n")

    per_query_results = []

    for item in EVAL_SET:
        qid = item["id"]
        query = item["query"]
        reference = item["reference"]
        relevant_ids = item.get("relevant_ids", [])

        print(f"\n--- [{run_type}] {qid}: {query} ---")

        if cold_cache:
            clear_mcp_cache()

        t0 = time.time()
        result = invoke_with_logging(query)
        t1 = time.time()

        final_answer = result.get("final_answer", "")
        logging_meta = result.get("_logging", {})
        exec_stats = logging_meta.get("execution_stats", {})

        # Latency
        latency_ms_logged = exec_stats.get("total_duration_ms")
        latency_ms_wall = (t1 - t0) * 1000.0
        latency_ms = latency_ms_logged or latency_ms_wall

        # ROUGE & BLEU
        rouge = compute_rouge_l(reference, final_answer)
        bleu = compute_bleu(reference, final_answer)

        # Precision@K
        pred_ids = extract_retrieved_ids(result)
        p_at_k = precision_at_k(pred_ids, relevant_ids, K)

        # Cost
        cost = estimate_cost(exec_stats)

        per_query_results.append(
            {
                "id": qid,
                "query": query,
                "reference": reference,
                "answer": final_answer,
                "rouge_l": rouge,
                "bleu": bleu,
                "precision_at_k": p_at_k,
                "latency_ms": latency_ms,
                "cost": cost,
            }
        )

        print(f"  ROUGE-L:       {rouge:.4f}" if rouge is not None else "  ROUGE-L:       (skipped)")
        print(f"  BLEU:          {bleu:.4f}" if bleu is not None else "  BLEU:          (skipped)")
        print(f"  Precision@{K}: {p_at_k:.4f}" if p_at_k is not None else f"  Precision@{K}: (no labels)")
        print(f"  Latency:       {latency_ms:.1f} ms")
        if cost is not None:
            print(f"  Cost:          ${cost:.5f}")
        else:
            print("  Cost:          (tokens not logged)")

    # Aggregate metrics
    def avg(values: List[Optional[float]]) -> Optional[float]:
        vals = [v for v in values if v is not None]
        return statistics.mean(vals) if vals else None

    summary = {
        "run_type": run_type,
        "avg_rouge_l": avg([r["rouge_l"] for r in per_query_results]),
        "avg_bleu": avg([r["bleu"] for r in per_query_results]),
        "avg_precision_at_20": avg([r["precision_at_20"] for r in per_query_results]),
        "avg_latency_ms": avg([r["latency_ms"] for r in per_query_results]),
        "avg_cost": avg([r["cost"] for r in per_query_results]),
        "per_query": per_query_results,
    }

    return summary

# %%
cold_summary = run_eval(cold_cache=True)
warm_summary = run_eval(cold_cache=False)
# Out:
# ===== EVALUATION RUN (COLD CACHE) =====
#
#
# --- [COLD] q1: Find me a wooden puzzle for kids under $20 ---
# [CACHE] Cleared rag_cache and web_cache
#
# [ROUTER] Extracted intent: {'product_type': 'puzzle', 'budget': None, 'price_min': None, 'price_max': 20.0, 'category': 'Toys', 'eco_friendly': None, 'materials': ['wood'], 'age_range': 'kids', 'brand': None}
#
# [SAFETY] Is safe: True
#
# [PLANNER] Plan: Search 2020 catalog, then verify current web prices for comparison
# [PLANNER] Tools: ['rag.search', 'web.search']
# [PLANNER] RAG params: {'query': 'wooden kids puzzle', 'price_min': None, 'price_max': 20.0, 'category': 'Toys', 'eco_friendly': None, 'top_k': 5}
#
# [EXECUTOR] Calling rag.search...
# [EXECUTOR] RAG found: 5 products
#
# [EXECUTOR] Calling web.search (Google Shopping via MCP)...
# [EXECUTOR] Price filter: under $20.0
# [EXECUTOR] Running 5 price checks in PARALLEL...
# [EXECUTOR] ✓ Melissa & Doug Barnyard Wooden Jigsaw Pu... → 40 results
# [EXECUTOR] ✓ Mudpuppy 4-Layer Transportation Friends ... → 9 results
# [EXECUTOR] ✓ Dragon Boat... → 40 results
# [EXECUTOR] ✓ Melissa & Doug Personalized Vehicles Woo... → 40 results
# [EXECUTOR] ✓ The Learning Journey My First Big Floor ... → 11 results
# [EXECUTOR] Parallel checks done in 3109ms
# [EXECUTOR] Searching alternatives: 'find me a wooden puzzle for kids under $20'...
# [EXECUTOR] Found 40 alternatives
# [EXECUTOR] Price filter: 180 → 126 results ($0-$20.0)
# [EXECUTOR] Total: 126 web results
#
# [RECONCILER] Starting reconciliation...
# [RECONCILER] RAG results: 5, Web results: 126
# [RECONCILER] Matched 4 products
# [RECONCILER] Found 4 conflicts
# [RECONCILER] Created comparison table with 127 entries
# [RECONCILER] Example match: 'Dragon Boat...' <-> 'Miniature Dragon Boat...' (score: 0.59)
# [RECONCILER] Example conflict: Catalog shows $12.99, web shows $0.50 (96.2% difference)
#
# [SYNTHESIZER] Generated answer with 2 unique citations
# [SYNTHESIZER] Total citations (with 9 unique web sources): 11
#
# [TTS DEBUG] has_catalog_items: True, has_web_only_items: False
# [TTS DEBUG] Products for voice:
# 1. Dragon Boat at $12.99 from our catalog, currently $0.50 at Millennium Games
# 2. Melissa & Doug Barnyard Wooden Jigsaw Puzzle (24 pcs) at $7.99 from our catalog, currently $13.99 at Melissa & Doug
# 3. Melissa & Doug Personalized Vehicles Wooden Peg Puzzle with Sound Effects (8 Piece) at $18.29 from our catalog, currently $10.99 at Melissa & Doug
#
#   ROUGE-L:       0.1579
#   BLEU:          0.0140
#   Precision@5: 0.0000
#   Latency:       16411.3 ms
#   Cost:          (tokens not logged)
#
# --- [COLD] q2: I need a stainless steel cleaner that’s eco-friendly and under $15 ---
# [CACHE] Cleared rag_cache and web_cache
#
# [ROUTER] Extracted intent: {'product_type': 'stainless steel cleaner', 'budget': None, 'price_min': None, 'price_max': 15.0, 'category': None, 'eco_friendly': True, 'materials': None, 'age_range': None, 'brand': None}
#
# [SAFETY] Is safe: True
#
# [PLANNER] Plan: Search 2020 catalog, then verify current web prices for comparison
# [PLANNER] Tools: ['rag.search', 'web.search']
# [PLANNER] RAG params: {'query': 'eco-friendly stainless cleaner', 'price_min': None, 'price_max': 15.0, 'category': None, 'eco_friendly': True, 'top_k': 5}
#
# [EXECUTOR] Calling rag.search...
# [EXECUTOR] RAG found: 0 products
#
# [EXECUTOR] Calling web.search (Google Shopping via MCP)...
# [EXECUTOR] Price filter: under $15.0
# [EXECUTOR] Searching alternatives: 'i need a stainless steel cleaner that’s eco-friendly and under $15'...
# [EXECUTOR] Found 40 alternatives
# [EXECUTOR] Price filter: 40 → 40 results ($0-$15.0)
# [EXECUTOR] Total: 40 web results
#
# [RECONCILER] Starting reconciliation...
# [RECONCILER] RAG results: 0, Web results: 40
# [RECONCILER] No RAG results to reconcile
#
# [SYNTHESIZER] Generated answer with 0 unique citations
# [SYNTHESIZER] Total citations (with 13 unique web sources): 13
#
# [TTS DEBUG] has_catalog_items: False, has_web_only_items: True
# [TTS DEBUG] Products for voice:
# 1. Weiman Stainless Steel Cleaner Polish at $4.72 from Walmart
# 2. Weiman Stainless Steel Wipes at $4.79 from Target
# 3. Eco-Me Lemon Fresh Stainless Steel Polish at $10.99 from Vitacost.com
#
#   ROUGE-L:       0.1159
#   BLEU:          0.0170
#   Precision@5: 0.0000
#   Latency:       20388.4 ms
#   Cost:          (tokens not logged)
#
# --- [COLD] q3: Show me eco-friendly toys under $15 for a 4 year old ---
# [CACHE] Cleared rag_cache and web_cache
#
# [ROUTER] Extracted intent: {'product_type': 'toy', 'budget': None, 'price_min': None, 'price_max': 15.0, 'category': 'Toys', 'eco_friendly': True, 'materials': None, 'age_range': '4 year old', 'brand': None}
#
# [SAFETY] Is safe: True
#
# [PLANNER] Plan: Search 2020 catalog, then verify current web prices for comparison
# [PLANNER] Tools: ['rag.search', 'web.search']
# [PLANNER] RAG params: {'query': 'eco-friendly toys', 'price_min': None, 'price_max': 15.0, 'category': 'Toys', 'eco_friendly': True, 'top_k': 5}
#
# [EXECUTOR] Calling rag.search...
# [EXECUTOR] RAG found: 5 products
#
# [EXECUTOR] Calling web.search (Google Shopping via MCP)...
# [EXECUTOR] Price filter: under $15.0
# [EXECUTOR] Running 5 price checks in PARALLEL...
# [EXECUTOR] ✓ Green Toys Race Car-Pink... → 40 results
# [EXECUTOR] ✓ Green Toys Convertible Vehicle with Char... → 40 results
# [EXECUTOR] ✓ Green Toys Fire Engine... → 40 results
# [EXECUTOR] ✓ green sprouts Adventure Friends made fro... → 4 results
# [EXECUTOR] ⏱️ Timeout for Green Toys Dump Truck Puzzle (... (skipped)
# [EXECUTOR] ⊘ Green Toys Dump Truck Puzzle (4 Piece)... → 0 results (timeout or error)
# [EXECUTOR] Parallel checks done in 38093ms
# [EXECUTOR] Searching alternatives: 'show me eco-friendly toys under $15 for a 4 year old'...
# [EXECUTOR] Found 40 alternatives
# [EXECUTOR] Price filter: 164 → 99 results ($0-$15.0)
# [EXECUTOR] Total: 99 web results
#
# [RECONCILER] Starting reconciliation...
# [RECONCILER] RAG results: 5, Web results: 99
# [RECONCILER] Matched 4 products
# [RECONCILER] Found 1 conflicts
# [RECONCILER] Created comparison table with 102 entries
# [RECONCILER] Example match: 'Green Toys Dump Truck Puzzle (4 Piece)...' <-> 'Green Toys Race Car...' (score: 0.737)
# [RECONCILER] Example conflict: Catalog shows $6.51, web shows $8.00 (22.9% difference)
#
# [SYNTHESIZER] Generated answer with 4 unique citations
# [SYNTHESIZER] Total citations (with 9 unique web sources): 13
#
# [TTS DEBUG] has_catalog_items: True, has_web_only_items: False
# [TTS DEBUG] Products for voice:
# 1. Green Toys Dump Truck Puzzle (4 Piece) at $10.31 from our catalog
# 2. Green Toys Convertible Vehicle with Character at $6.51 from our catalog, currently $8.00 at eBay
# 3. Green Toys Race Car-Pink at $9.59 from our catalog, currently $10.99 at Green Toys
#
#   ROUGE-L:       0.1554
#   BLEU:          0.0150
#   Precision@5: 0.0000
#   Latency:       58690.3 ms
#   Cost:          (tokens not logged)
#
# --- [COLD] q4: Recommend a reusable stainless steel water bottle 32 ounce under $25 ---
# [CACHE] Cleared rag_cache and web_cache
#
# [ROUTER] Extracted intent: {'product_type': 'water bottle', 'budget': None, 'price_min': None, 'price_max': 25.0, 'category': None, 'eco_friendly': None, 'materials': ['stainless steel'], 'age_range': None, 'brand': None}
#
# [SAFETY] Is safe: True
#
# [PLANNER] Plan: Search 2020 catalog, then verify current web prices for comparison
# [PLANNER] Tools: ['rag.search', 'web.search']
# [PLANNER] RAG params: {'query': 'stainless steel water bottle', 'price_min': None, 'price_max': 25.0, 'category': None, 'eco_friendly': None, 'top_k': 5}
#
# [EXECUTOR] Calling rag.search...
# [EXECUTOR] RAG found: 0 products
#
# [EXECUTOR] Calling web.search (Google Shopping via MCP)...
# [EXECUTOR] Price filter: under $25.0
# [EXECUTOR] Searching alternatives: 'recommend a reusable stainless steel water bottle 32 ounce under $25'...
# [EXECUTOR] Found 40 alternatives
# [EXECUTOR] Price filter: 40 → 39 results ($0-$25.0)
# [EXECUTOR] Total: 39 web results
#
# [RECONCILER] Starting reconciliation...
# [RECONCILER] RAG results: 0, Web results: 39
# [RECONCILER] No RAG results to reconcile
#
# [SYNTHESIZER] Generated answer with 0 unique citations
# [SYNTHESIZER] Total citations (with 10 unique web sources): 10
#
# [TTS DEBUG] has_catalog_items: False, has_web_only_items: True
# [TTS DEBUG] Products for voice:
# 1. Ozark Trail 32 oz Insulated Stainless Steel Wide Mouth Water Bottle at $13.73 from Walmart
# 2. RTIC 32 oz Ceramic Lined Insulated Outback Bottle at $16.09 from RTIC Outdoors
# 3. Embark Stainless Steel Hydration Water Bottle at $15.00 from Target
#
#   ROUGE-L:       0.1392
#   BLEU:          0.0267
#   Precision@5: 0.0000
#   Latency:       24332.4 ms
#   Cost:          (tokens not logged)
#
# --- [COLD] q5: Lunch box under $30 ---
# [CACHE] Cleared rag_cache and web_cache
#
# [ROUTER] Extracted intent: {'product_type': 'lunch box', 'budget': None, 'price_min': None, 'price_max': 30.0, 'category': None, 'eco_friendly': None, 'materials': None, 'age_range': None, 'brand': None}
#
# [SAFETY] Is safe: True
#
# [PLANNER] Plan: Search 2020 catalog, then verify current web prices for comparison
# [PLANNER] Tools: ['rag.search', 'web.search']
# [PLANNER] RAG params: {'query': 'lunch box', 'price_min': None, 'price_max': 30.0, 'category': None, 'eco_friendly': None, 'top_k': 5}
#
# [EXECUTOR] Calling rag.search...
# [EXECUTOR] RAG found: 5 products
#
# [EXECUTOR] Calling web.search (Google Shopping via MCP)...
# [EXECUTOR] Price filter: under $30.0
# [EXECUTOR] Running 5 price checks in PARALLEL...
# [EXECUTOR] ✓ Suck UK TV Lunch Box I Food Storage Cont... → 38 results
# [EXECUTOR] ✓ Wildkin 33417 Olive Kids Fairy Princess ... → 2 results
# [EXECUTOR] ✓ lunch bag Bag001 Reusable Zip Closure Ha... → 40 results
# [EXECUTOR] ✓ Bento Box Style 2 Layer Lunchbox by Asve... → 40 results
# [EXECUTOR] ✓ Wildkin 33527 Rip-Stop Black/Green Box L... → 6 results
# [EXECUTOR] Parallel checks done in 33492ms
# [EXECUTOR] Searching alternatives: 'lunch box under $30'...
# [EXECUTOR] Found 40 alternatives
# [EXECUTOR] Price filter: 166 → 124 results ($0-$30.0)
# [EXECUTOR] Total: 124 web results
#
# [RECONCILER] Starting reconciliation...
# [RECONCILER] RAG results: 5, Web results: 124
# [RECONCILER] Matched 3 products
# [RECONCILER] Found 2 conflicts
# [RECONCILER] Created comparison table with 126 entries
# [RECONCILER] Example match: 'Bento Box Style 2 Layer Lunchbox by Asvel...' <-> 'Bento lunch box set 2 tier blue 850ml...' (score: 0.738)
# [RECONCILER] Example conflict: Catalog shows $12.59, web shows $10.00 (20.6% difference)
#
# [SYNTHESIZER] Generated answer with 5 unique citations
# [SYNTHESIZER] Total citations (with 11 unique web sources): 16
#
# [TTS DEBUG] has_catalog_items: True, has_web_only_items: False
# [TTS DEBUG] Products for voice:
# 1. Bento Box Style 2 Layer Lunchbox by Asvel at $17.99 from our catalog, currently $15.99 at Bento USA
# 2. Wildkin 33527 Rip-Stop Black/Green Box Lunch Bags, One Size at $12.59 from our catalog, currently $10.00 at Wildkin
# 3. Wildkin 33417 Olive Kids Fairy Princess Lunch Box at $13.41 from our catalog, currently $24.99 at Walmart
#
#   ROUGE-L:       0.0520
#   BLEU:          0.0041
#   Precision@5: 0.0000
#   Latency:       55529.6 ms
#   Cost:          (tokens not logged)
#
# --- [COLD] q6: I want a LEGO building set for kids around $30 ---
# [CACHE] Cleared rag_cache and web_cache
#
# [ROUTER] Extracted intent: {'product_type': 'toy', 'budget': 30.0, 'price_min': None, 'price_max': None, 'category': 'Toys', 'eco_friendly': None, 'materials': None, 'age_range': 'kids', 'brand': 'LEGO'}
#
# [SAFETY] Is safe: True
#
# [PLANNER] Plan: Search 2020 catalog, then verify current web prices for comparison
# [PLANNER] Tools: ['rag.search', 'web.search']
# [PLANNER] RAG params: {'query': 'LEGO kids set', 'price_min': None, 'price_max': 30.0, 'category': 'Toys', 'eco_friendly': None, 'top_k': 5}
#
# [EXECUTOR] Calling rag.search...
# [EXECUTOR] RAG found: 5 products
#
# [EXECUTOR] Calling web.search (Google Shopping via MCP)...
# [EXECUTOR] Running 5 price checks in PARALLEL...
# [EXECUTOR] ✓ LEGO Friends Heartlake Surf Shop 41315 B... → 16 results
# [EXECUTOR] ✓ LEGO Classic World Fun 10403 Building Ki... → 4 results
# [EXECUTOR] ✓ LEGO City Rover Testing Drive 60225 Buil... → 2 results
# [EXECUTOR] ✓ LEGO Classic Creative Suitcase 10713 Bui... → 37 results
# [EXECUTOR] ✓ LEGO City Dirt Road Pursuit 60172 Buildi... → 11 results
# [EXECUTOR] Parallel checks done in 34845ms
# [EXECUTOR] Searching alternatives: 'i want a lego building set for kids around $30'...
# [EXECUTOR] Found 22 alternatives
# [EXECUTOR] Total: 92 web results
#
# [RECONCILER] Starting reconciliation...
# [RECONCILER] RAG results: 5, Web results: 92
# [RECONCILER] Matched 5 products
# [RECONCILER] Found 3 conflicts
# [RECONCILER] Created comparison table with 93 entries
# [RECONCILER] Example match: 'LEGO City Dirt Road Pursuit 60172 Building Kit (29...' <-> 'LEGO City Blue Monster Truck 60402...' (score: 0.61)
# [RECONCILER] Example conflict: Catalog shows $14.59, web shows $34.99 (139.8% difference)
#
# [SYNTHESIZER] Generated answer with 2 unique citations
# [SYNTHESIZER] Total citations (with 8 unique web sources): 10
#
# [TTS DEBUG] has_catalog_items: True, has_web_only_items: False
# [TTS DEBUG] Products for voice:
# 1. LEGO City Dirt Road Pursuit 60172 Building Kit (297 Pieces) at $29.00 from our catalog, currently $25.85 at Walmart
# 2. LEGO Classic World Fun 10403 Building Kit (295 Piece) at $14.59 from our catalog, currently $34.99 at LEGO.com
# 3. LEGO Classic Creative Suitcase 10713 Building Kit (213 Pieces) at $19.78 from our catalog, currently $34.99 at LEGO.com
#
#   ROUGE-L:       0.1486
#   BLEU:          0.0132
#   Precision@5: 0.0000
#   Latency:       57549.8 ms
#   Cost:          (tokens not logged)
#
# --- [COLD] q7: Show me a non-stick frying pan under $40 that works on induction ---
# [CACHE] Cleared rag_cache and web_cache
#
# [ROUTER] Extracted intent: {'product_type': 'frying pan', 'budget': None, 'price_min': None, 'price_max': 40.0, 'category': None, 'eco_friendly': None, 'materials': None, 'age_range': None, 'brand': None}
#
# [SAFETY] Is safe: True
#
# [PLANNER] Plan: Search 2020 catalog, then verify current web prices for comparison
# [PLANNER] Tools: ['rag.search', 'web.search']
# [PLANNER] RAG params: {'query': 'non-stick frying pan', 'price_min': None, 'price_max': 40.0, 'category': None, 'eco_friendly': None, 'top_k': 5}
#
# [EXECUTOR] Calling rag.search...
# [EXECUTOR] RAG found: 0 products
#
# [EXECUTOR] Calling web.search (Google Shopping via MCP)...
# [EXECUTOR] Price filter: under $40.0
# [EXECUTOR] Searching alternatives: 'show me a non-stick frying pan under $40 that works on induction'...
# [EXECUTOR] Found 40 alternatives
# [EXECUTOR] Price filter: 40 → 40 results ($0-$40.0)
# [EXECUTOR] Total: 40 web results
#
# [RECONCILER] Starting reconciliation...
# [RECONCILER] RAG results: 0, Web results: 40
# [RECONCILER] No RAG results to reconcile
#
# [SYNTHESIZER] Generated answer with 0 unique citations
# [SYNTHESIZER] Total citations (with 7 unique web sources): 7
#
# [TTS DEBUG] has_catalog_items: False, has_web_only_items: True
# [TTS DEBUG] Products for voice:
# 1. Carote Nonstick Frying Pan 8" Skillet with Induction at $11.97 from Walmart
# 2. Anolon Achieve Hard Anodized Nonstick Frying Pan at $32.99 from Target
# 3. Thyme & Table Granite Collection Fry Pan at $24.86 from Walmart
#
#   ROUGE-L:       0.1231
#   BLEU:          0.0112
#   Precision@5: 0.0000
#   Latency:       15779.5 ms
#   Cost:          (tokens not logged)
#
# --- [COLD] q8: Skateboard under $60 ---
# [CACHE] Cleared rag_cache and web_cache
#
# [ROUTER] Extracted intent: {'product_type': 'skateboard', 'budget': None, 'price_min': None, 'price_max': 60.0, 'category': None, 'eco_friendly': None, 'materials': None, 'age_range': None, 'brand': None}
#
# [SAFETY] Is safe: True
#
# [PLANNER] Plan: Search 2020 catalog, then verify current web prices for comparison
# [PLANNER] Tools: ['rag.search', 'web.search']
# [PLANNER] RAG params: {'query': 'skateboard', 'price_min': None, 'price_max': 60.0, 'category': None, 'eco_friendly': None, 'top_k': 5}
#
# [EXECUTOR] Calling rag.search...
# [EXECUTOR] RAG found: 5 products
#
# [EXECUTOR] Calling web.search (Google Shopping via MCP)...
# [EXECUTOR] Price filter: under $60.0
# [EXECUTOR] Running 5 price checks in PARALLEL...
# [EXECUTOR] ✓ Kryptonics Mini Cutaway Cruiser Skateboa... → 40 results
# [EXECUTOR] ✓ Punisher Skateboards Elephantasm Complet... → 37 results
# [EXECUTOR] ✓ Punisher Skateboards MAYAN Complete Skat... → 40 results
# [EXECUTOR] ✓ Ferrari Double Kick Skateboard... → 34 results
# [EXECUTOR] ✓ Quest QT-NSC44C The Super Cruiser The Or... → 7 results
# [EXECUTOR] Parallel checks done in 32264ms
# [EXECUTOR] Searching alternatives: 'skateboard under $60'...
# [EXECUTOR] Found 40 alternatives
# [EXECUTOR] Price filter: 198 → 104 results ($0-$60.0)
# [EXECUTOR] Total: 104 web results
#
# [RECONCILER] Starting reconciliation...
# [RECONCILER] RAG results: 5, Web results: 104
# [RECONCILER] Matched 5 products
# [RECONCILER] Found 4 conflicts
# [RECONCILER] Created comparison table with 104 entries
# [RECONCILER] Example match: 'Punisher Skateboards Elephantasm Complete 31-Inch ...' <-> 'PUNISHER SKATEBOARDS | A-FRAME SERIES | DAVE SMITH...' (score: 0.75)
# [RECONCILER] Example conflict: Catalog shows $39.99, web shows $59.99 (50.0% difference)
#
# [SYNTHESIZER] Generated answer with 5 unique citations
# [SYNTHESIZER] Total citations (with 5 unique web sources): 10
#
# [TTS DEBUG] has_catalog_items: True, has_web_only_items: False
# [TTS DEBUG] Products for voice:
# 1. Punisher Skateboards Elephantasm Complete 31-Inch Skateboard All Maple at $39.99 from our catalog, currently $59.99 at Punisher Skateboards
# 2. Ferrari Double Kick Skateboard at $38.16 from our catalog, currently $30.00 at eBay
# 3. Punisher Skateboards MAYAN Complete Skateboard with Convace Deck at $57.16 from our catalog, currently $59.99 at Punisher Skateboards
#
#   ROUGE-L:       0.0524
#   BLEU:          0.0028
#   Precision@5: 0.0000
#   Latency:       50256.9 ms
#   Cost:          (tokens not logged)
#
# --- [COLD] q9: Party decorations under $100 ---
# [CACHE] Cleared rag_cache and web_cache
#
# [ROUTER] Extracted intent: {'product_type': 'party decorations', 'budget': None, 'price_min': None, 'price_max': 100.0, 'category': None, 'eco_friendly': None, 'materials': None, 'age_range': None, 'brand': None}
#
# [SAFETY] Is safe: True
#
# [PLANNER] Plan: Search 2020 catalog, then verify current web prices for comparison
# [PLANNER] Tools: ['rag.search', 'web.search']
# [PLANNER] RAG params: {'query': 'party decorations', 'price_min': None, 'price_max': 100.0, 'category': None, 'eco_friendly': None, 'top_k': 5}
#
# [EXECUTOR] Calling rag.search...
# [EXECUTOR] RAG found: 5 products
#
# [EXECUTOR] Calling web.search (Google Shopping via MCP)...
# [EXECUTOR] Price filter: under $100.0
# [EXECUTOR] Running 5 price checks in PARALLEL...
# [EXECUTOR] ✓ Amscan 241143 Party Décor, Assorted Size... → 5 results
# [EXECUTOR] ⊘ Amscan 181576 Measures Party Needs, Mult... → 0 results (timeout or error)
# [EXECUTOR] ✓ LOAZRE Unicorn Backdrop Party Supplies D... → 40 results
# [EXECUTOR] ✓ Creative Converting 033023 Party Supplie... → 11 results
# [EXECUTOR] ✓ Amscan 241286 Party Décor, Multi Size, M... → 32 results
# [EXECUTOR] Parallel checks done in 28474ms
# [EXECUTOR] Searching alternatives: 'party decorations under $100'...
# [EXECUTOR] Found 40 alternatives
# [EXECUTOR] Price filter: 128 → 121 results ($0-$100.0)
# [EXECUTOR] Total: 121 web results
#
# [RECONCILER] Starting reconciliation...
# [RECONCILER] RAG results: 5, Web results: 121
# [RECONCILER] Matched 2 products
# [RECONCILER] Found 2 conflicts
# [RECONCILER] Created comparison table with 125 entries
# [RECONCILER] Example match: 'Amscan 181576 Measures Party Needs, Multi Color...' <-> 'Amscan Party Supplies, Multicolor...' (score: 0.576)
# [RECONCILER] Example conflict: Catalog shows $8.20, web shows $11.67 (42.3% difference)
#
# [SYNTHESIZER] Generated answer with 5 unique citations
# [SYNTHESIZER] Total citations (with 9 unique web sources): 14
#
# [TTS DEBUG] has_catalog_items: True, has_web_only_items: False
# [TTS DEBUG] Products for voice:
# 1. Amscan 181576 Measures Party Needs, Multi Color at $8.20 from our catalog, currently $11.67 at eBay
# 2. Amscan 241286 Party Décor, Multi Size, Multicolor at $9.69 from our catalog, currently $11.67 at eBay
# 3. Creative Converting 033023 Party Supplies, Black/Orange at $3.39 from our catalog
#
#   ROUGE-L:       0.0703
#   BLEU:          0.0047
#   Precision@5: 0.0000
#   Latency:       50038.3 ms
#   Cost:          (tokens not logged)
#
# --- [COLD] q10: I need an ergonomic office chair under $250 ---
# [CACHE] Cleared rag_cache and web_cache
#
# [ROUTER] Extracted intent: {'product_type': 'office chair', 'budget': 250, 'price_min': None, 'price_max': 250, 'category': None, 'eco_friendly': None, 'materials': None, 'age_range': None, 'brand': None}
#
# [SAFETY] Is safe: True
#
# [PLANNER] Plan: Search 2020 catalog, then verify current web prices for comparison
# [PLANNER] Tools: ['rag.search', 'web.search']
# [PLANNER] RAG params: {'query': 'ergonomic office chair', 'price_min': None, 'price_max': 250, 'category': None, 'eco_friendly': None, 'top_k': 5}
#
# [EXECUTOR] Calling rag.search...
# [EXECUTOR] RAG found: 5 products
#
# [EXECUTOR] Calling web.search (Google Shopping via MCP)...
# [EXECUTOR] Price filter: under $250
# [EXECUTOR] Running 5 price checks in PARALLEL...
# [EXECUTOR] ✓ Flash Furniture Black Padded Ergonomic S... → 40 results
# [EXECUTOR] ✓ Ergo Furnishings E-Z Molded Plastic Stac... → 34 results
# [EXECUTOR] ✓ Learniture Shapes Series Vinyl Soft Seat... → 34 results
# [EXECUTOR] ✓ ioHOMES Kiddy Contemporary Microfiber Up... → 3 results
# [EXECUTOR] ⊘ Leffler Home Kids Chair, Red... → 0 results (timeout or error)
# [EXECUTOR] Parallel checks done in 16573ms
# [EXECUTOR] Searching alternatives: 'i need an ergonomic office chair under $250'...
# [EXECUTOR] Found 40 alternatives
# [EXECUTOR] Price filter: 151 → 112 results ($0-$250)
# [EXECUTOR] Total: 112 web results
#
# [RECONCILER] Starting reconciliation...
# [RECONCILER] RAG results: 5, Web results: 112
# [RECONCILER] Matched 1 products
# [RECONCILER] Found 1 conflicts
# [RECONCILER] Created comparison table with 116 entries
# [RECONCILER] Example match: 'Flash Furniture Black Padded Ergonomic Shell Chair...' <-> 'Flash Furniture Black Padded Ergonomic Shell Chair...' (score: 0.674)
# [RECONCILER] Example conflict: Catalog shows $44.99, web shows $125.99 (180.0% difference)
#
# [SYNTHESIZER] Generated answer with 0 unique citations
# [SYNTHESIZER] Total citations (with 13 unique web sources): 13
#
# [TTS DEBUG] has_catalog_items: True, has_web_only_items: False
# [TTS DEBUG] Products for voice:
# 1. Flash Furniture Black Padded Ergonomic Shell Chair with Left Handed Flip-Up Tablet Arm at $44.99 from our catalog, currently $125.99 at Engineer Warehouse
# 2. Ergo Furnishings E-Z Molded Plastic Stackable Chair Stool (Set of 2), Green at $78.57 from our catalog
# 3. ioHOMES Kiddy Contemporary Microfiber Upholstered Creature Foldable Frog Lounge Chair with Doubles As Booster Seat, Green at $57.94 from our catalog
#
#   ROUGE-L:       0.0946
#   BLEU:          0.0097
#   Precision@5: 0.0000
#   Latency:       40554.2 ms
#   Cost:          (tokens not logged)
#
# ===== EVALUATION RUN (WARM CACHE) =====
#
#
# --- [WARM] q1: Find me a wooden puzzle for kids under $20 ---
#
# [ROUTER] Extracted intent: {'product_type': 'puzzle', 'budget': None, 'price_min': None, 'price_max': 20.0, 'category': 'Toys', 'eco_friendly': None, 'materials': ['wood'], 'age_range': 'kids', 'brand': None}
#
# [SAFETY] Is safe: True
#
# [PLANNER] Plan: Search 2020 catalog, then verify current web prices for comparison
# [PLANNER] Tools: ['rag.search', 'web.search']
# [PLANNER] RAG params: {'query': 'wooden kids puzzle', 'price_min': None, 'price_max': 20.0, 'category': 'Toys', 'eco_friendly': None, 'top_k': 5}
#
# [EXECUTOR] Calling rag.search...
# [EXECUTOR] RAG found: 5 products
#
# [EXECUTOR] Calling web.search (Google Shopping via MCP)...
# [EXECUTOR] Price filter: under $20.0
# [EXECUTOR] Running 5 price checks in PARALLEL...
# [EXECUTOR] ✓ Melissa & Doug Barnyard Wooden Jigsaw Pu... → 40 results
# [EXECUTOR] ✓ Melissa & Doug Personalized Vehicles Woo... → 40 results
# [EXECUTOR] ✓ Mudpuppy 4-Layer Transportation Friends ... → 9 results
# [EXECUTOR] ✓ Dragon Boat... → 40 results
# [EXECUTOR] ⊘ The Learning Journey My First Big Floor ... → 0 results (timeout or error)
# [EXECUTOR] Parallel checks done in 7768ms
# [EXECUTOR] Searching alternatives: 'find me a wooden puzzle for kids under $20'...
# [EXECUTOR] Found 40 alternatives
# [EXECUTOR] Price filter: 169 → 119 results ($0-$20.0)
# [EXECUTOR] Total: 119 web results
#
# [RECONCILER] Starting reconciliation...
# [RECONCILER] RAG results: 5, Web results: 119
# [RECONCILER] Matched 4 products
# [RECONCILER] Found 4 conflicts
# [RECONCILER] Created comparison table with 120 entries
# [RECONCILER] Example match: 'Melissa & Doug Barnyard Wooden Jigsaw Puzzle (24 p...' <-> 'Melissa & Doug African Plains Jigsaw Puzzle...' (score: 0.892)
# [RECONCILER] Example conflict: Catalog shows $7.99, web shows $13.99 (75.1% difference)
#
# [SYNTHESIZER] Generated answer with 4 unique citations
# [SYNTHESIZER] Total citations (with 9 unique web sources): 13
#
# [TTS DEBUG] has_catalog_items: True, has_web_only_items: False
# [TTS DEBUG] Products for voice:
# 1. Melissa & Doug Barnyard Wooden Jigsaw Puzzle (24 pcs) at $7.99 from our catalog, currently $13.99 at Melissa & Doug
# 2. Dragon Boat at $12.99 from our catalog, currently $0.50 at Millennium Games
# 3. Mudpuppy 4-Layer Transportation Friends 12Piece Wood Jigsaw Puzzle, Ages 2+ - Colorful Vehicle Illustrations, Multicolor at $17.99 from our catalog, currently $11.99 at Mudpuppy
#
#   ROUGE-L:       0.1297
#   BLEU:          0.0116
#   Precision@5: 0.0000
#   Latency:       24249.6 ms
#   Cost:          (tokens not logged)
#
# --- [WARM] q2: I need a stainless steel cleaner that’s eco-friendly and under $15 ---
#
# [ROUTER] Extracted intent: {'product_type': 'stainless steel cleaner', 'budget': None, 'price_min': None, 'price_max': 15.0, 'category': None, 'eco_friendly': True, 'materials': None, 'age_range': None, 'brand': None}
#
# [SAFETY] Is safe: True
#
# [PLANNER] Plan: Search 2020 catalog, then verify current web prices for comparison
# [PLANNER] Tools: ['rag.search', 'web.search']
# [PLANNER] RAG params: {'query': 'eco-friendly stainless cleaner', 'price_min': None, 'price_max': 15.0, 'category': None, 'eco_friendly': True, 'top_k': 5}
#
# [EXECUTOR] Calling rag.search...
# [EXECUTOR] RAG found: 0 products
#
# [EXECUTOR] Calling web.search (Google Shopping via MCP)...
# [EXECUTOR] Price filter: under $15.0
# [EXECUTOR] Searching alternatives: 'i need a stainless steel cleaner that’s eco-friendly and under $15'...
# [EXECUTOR] Found 0 alternatives
# [EXECUTOR] Price filter: 0 → 0 results ($0-$15.0)
# [EXECUTOR] Total: 0 web results
#
# [RECONCILER] Starting reconciliation...
# [RECONCILER] RAG results: 0, Web results: 0
# [RECONCILER] No web results to reconcile
#
# [SYNTHESIZER] Generated answer with 0 unique citations
# [SYNTHESIZER] Total citations (with 0 unique web sources): 0
#   ROUGE-L:       0.1379
#   BLEU:          0.0236
#   Precision@5: 0.0000
#   Latency:       10441.2 ms
#   Cost:          (tokens not logged)
#
# --- [WARM] q3: Show me eco-friendly toys under $15 for a 4 year old ---
#
# [ROUTER] Extracted intent: {'product_type': 'toy', 'budget': None, 'price_min': None, 'price_max': 15.0, 'category': 'Toys', 'eco_friendly': True, 'materials': None, 'age_range': '4 year old', 'brand': None}
#
# [SAFETY] Is safe: True
#
# [PLANNER] Plan: Search 2020 catalog, then verify current web prices for comparison
# [PLANNER] Tools: ['rag.search', 'web.search']
# [PLANNER] RAG params: {'query': 'eco-friendly toys', 'price_min': None, 'price_max': 15.0, 'category': 'Toys', 'eco_friendly': True, 'top_k': 5}
#
# [EXECUTOR] Calling rag.search...
# [EXECUTOR] RAG found: 5 products
#
# [EXECUTOR] Calling web.search (Google Shopping via MCP)...
# [EXECUTOR] Price filter: under $15.0
# [EXECUTOR] Running 5 price checks in PARALLEL...
# [EXECUTOR] ✓ Green Toys Convertible Vehicle with Char... → 40 results
# [EXECUTOR] ✓ Green Toys Fire Engine... → 40 results
# [EXECUTOR] ✓ Green Toys Dump Truck Puzzle (4 Piece)... → 4 results
# [EXECUTOR] ✓ green sprouts Adventure Friends made fro... → 4 results
# [EXECUTOR] ⊘ Green Toys Race Car-Pink... → 0 results (timeout or error)
# [EXECUTOR] Parallel checks done in 9234ms
# [EXECUTOR] Searching alternatives: 'show me eco-friendly toys under $15 for a 4 year old'...
# [EXECUTOR] Found 0 alternatives
# [EXECUTOR] Price filter: 88 → 40 results ($0-$15.0)
# [EXECUTOR] Total: 40 web results
#
# [RECONCILER] Starting reconciliation...
# [RECONCILER] RAG results: 5, Web results: 40
# [RECONCILER] Matched 4 products
# [RECONCILER] Found 1 conflicts
# [RECONCILER] Created comparison table with 42 entries
# [RECONCILER] Example match: 'Green Toys Dump Truck Puzzle (4 Piece)...' <-> 'Green Toys Race Car...' (score: 0.737)
# [RECONCILER] Example conflict: Catalog shows $6.51, web shows $8.00 (22.9% difference)
#
# [SYNTHESIZER] Generated answer with 4 unique citations
# [SYNTHESIZER] Total citations (with 6 unique web sources): 10
#
# [TTS DEBUG] has_catalog_items: True, has_web_only_items: False
# [TTS DEBUG] Products for voice:
# 1. Green Toys Dump Truck Puzzle (4 Piece) at $10.31 from our catalog
# 2. Green Toys Race Car-Pink at $9.59 from our catalog, currently $10.99 at Green Toys
# 3. Green Toys Convertible Vehicle with Character at $6.51 from our catalog, currently $8.00 at eBay
#
#   ROUGE-L:       0.1808
#   BLEU:          0.0156
#   Precision@5: 0.0000
#   Latency:       22186.5 ms
#   Cost:          (tokens not logged)
#
# --- [WARM] q4: Recommend a reusable stainless steel water bottle 32 ounce under $25 ---
#
# [ROUTER] Extracted intent: {'product_type': 'water bottle', 'budget': None, 'price_min': None, 'price_max': 25.0, 'category': None, 'eco_friendly': None, 'materials': ['stainless steel'], 'age_range': None, 'brand': None}
#
# [SAFETY] Is safe: True
#
# [PLANNER] Plan: Search 2020 catalog, then verify current web prices for comparison
# [PLANNER] Tools: ['rag.search', 'web.search']
# [PLANNER] RAG params: {'query': 'stainless steel water bottle', 'price_min': None, 'price_max': 25.0, 'category': None, 'eco_friendly': None, 'top_k': 5}
#
# [EXECUTOR] Calling rag.search...
# [EXECUTOR] RAG found: 0 products
#
# [EXECUTOR] Calling web.search (Google Shopping via MCP)...
# [EXECUTOR] Price filter: under $25.0
# [EXECUTOR] Searching alternatives: 'recommend a reusable stainless steel water bottle 32 ounce under $25'...
# [EXECUTOR] Found 40 alternatives
# [EXECUTOR] Price filter: 40 → 39 results ($0-$25.0)
# [EXECUTOR] Total: 39 web results
#
# [RECONCILER] Starting reconciliation...
# [RECONCILER] RAG results: 0, Web results: 39
# [RECONCILER] No RAG results to reconcile
#
# [SYNTHESIZER] Generated answer with 0 unique citations
# [SYNTHESIZER] Total citations (with 10 unique web sources): 10
#
# [TTS DEBUG] has_catalog_items: False, has_web_only_items: True
# [TTS DEBUG] Products for voice:
# 1. Ozark Trail 32 oz Insulated Stainless Steel Wide Mouth Water Bottle at $13.73 from Walmart
# 2. RTIC 32 oz Ceramic Lined Insulated Outback Bottle at $16.09 from RTIC Outdoors
# 3. Embark Stainless Steel Hydration Water Bottle at $15.00 from Target
#
#   ROUGE-L:       0.1282
#   BLEU:          0.0254
#   Precision@5: 0.0000
#   Latency:       15344.5 ms
#   Cost:          (tokens not logged)
#
# --- [WARM] q5: Lunch box under $30 ---
#
# [ROUTER] Extracted intent: {'product_type': 'lunch box', 'budget': None, 'price_min': None, 'price_max': 30.0, 'category': None, 'eco_friendly': None, 'materials': None, 'age_range': None, 'brand': None}
#
# [SAFETY] Is safe: True
#
# [PLANNER] Plan: Search 2020 catalog, then verify current web prices for comparison
# [PLANNER] Tools: ['rag.search', 'web.search']
# [PLANNER] RAG params: {'query': 'lunch box', 'price_min': None, 'price_max': 30.0, 'category': None, 'eco_friendly': None, 'top_k': 5}
#
# [EXECUTOR] Calling rag.search...
# [EXECUTOR] RAG found: 5 products
#
# [EXECUTOR] Calling web.search (Google Shopping via MCP)...
# [EXECUTOR] Price filter: under $30.0
# [EXECUTOR] Running 5 price checks in PARALLEL...
# [EXECUTOR] ✓ Bento Box Style 2 Layer Lunchbox by Asve... → 40 results
# [EXECUTOR] ✓ Suck UK TV Lunch Box I Food Storage Cont... → 38 results
# [EXECUTOR] ✓ Wildkin 33417 Olive Kids Fairy Princess ... → 2 results
# [EXECUTOR] ✓ lunch bag Bag001 Reusable Zip Closure Ha... → 40 results
# [EXECUTOR] ✓ Wildkin 33527 Rip-Stop Black/Green Box L... → 6 results
# [EXECUTOR] Parallel checks done in 12951ms
# [EXECUTOR] Searching alternatives: 'lunch box under $30'...
# [EXECUTOR] Found 0 alternatives
# [EXECUTOR] Price filter: 126 → 84 results ($0-$30.0)
# [EXECUTOR] Total: 84 web results
#
# [RECONCILER] Starting reconciliation...
# [RECONCILER] RAG results: 5, Web results: 84
# [RECONCILER] Matched 3 products
# [RECONCILER] Found 2 conflicts
# [RECONCILER] Created comparison table with 86 entries
# [RECONCILER] Example match: 'Bento Box Style 2 Layer Lunchbox by Asvel...' <-> 'Bento lunch box set 2 tier blue 850ml...' (score: 0.738)
# [RECONCILER] Example conflict: Catalog shows $13.41, web shows $10.00 (25.4% difference)
#
# [SYNTHESIZER] Generated answer with 5 unique citations
# [SYNTHESIZER] Total citations (with 12 unique web sources): 17
#
# [TTS DEBUG] has_catalog_items: True, has_web_only_items: False
# [TTS DEBUG] Products for voice:
# 1. Bento Box Style 2 Layer Lunchbox by Asvel at $17.99 from our catalog, currently $15.99 at Bento USA
# 2. Wildkin 33417 Olive Kids Fairy Princess Lunch Box at $13.41 from our catalog, currently $10.00 at Wildkin
# 3. Wildkin 33527 Rip-Stop Black/Green Box Lunch Bags, One Size at $12.59 from our catalog, currently $29.99 at Wildkin
#
#   ROUGE-L:       0.0590
#   BLEU:          0.0046
#   Precision@5: 0.0000
#   Latency:       26958.0 ms
#   Cost:          (tokens not logged)
#
# --- [WARM] q6: I want a LEGO building set for kids around $30 ---
#
# [ROUTER] Extracted intent: {'product_type': 'toy', 'budget': 30.0, 'price_min': None, 'price_max': None, 'category': 'Toys', 'eco_friendly': None, 'materials': None, 'age_range': 'kids', 'brand': 'LEGO'}
#
# [SAFETY] Is safe: True
#
# [PLANNER] Plan: Search 2020 catalog, then verify current web prices for comparison
# [PLANNER] Tools: ['rag.search', 'web.search']
# [PLANNER] RAG params: {'query': 'LEGO kids set', 'price_min': None, 'price_max': 30.0, 'category': 'Toys', 'eco_friendly': None, 'top_k': 5}
#
# [EXECUTOR] Calling rag.search...
# [EXECUTOR] RAG found: 5 products
#
# [EXECUTOR] Calling web.search (Google Shopping via MCP)...
# [EXECUTOR] Running 5 price checks in PARALLEL...
# [EXECUTOR] ✓ LEGO Classic World Fun 10403 Building Ki... → 4 results
# [EXECUTOR] ✓ LEGO City Rover Testing Drive 60225 Buil... → 2 results
# [EXECUTOR] ✓ LEGO Classic Creative Suitcase 10713 Bui... → 37 results
# [EXECUTOR] ✓ LEGO City Dirt Road Pursuit 60172 Buildi... → 11 results
# [EXECUTOR] ✓ LEGO Friends Heartlake Surf Shop 41315 B... → 16 results
# [EXECUTOR] Parallel checks done in 4876ms
# [EXECUTOR] Searching alternatives: 'i want a lego building set for kids around $30'...
# [EXECUTOR] Found 22 alternatives
# [EXECUTOR] Total: 92 web results
#
# [RECONCILER] Starting reconciliation...
# [RECONCILER] RAG results: 5, Web results: 92
# [RECONCILER] Matched 5 products
# [RECONCILER] Found 3 conflicts
# [RECONCILER] Created comparison table with 93 entries
# [RECONCILER] Example match: 'LEGO Classic World Fun 10403 Building Kit (295 Pie...' <-> 'LEGO Classic Medium Creative Brick Box...' (score: 0.576)
# [RECONCILER] Example conflict: Catalog shows $14.59, web shows $34.99 (139.8% difference)
#
# [SYNTHESIZER] Generated answer with 4 unique citations
# [SYNTHESIZER] Total citations (with 9 unique web sources): 13
#
# [TTS DEBUG] has_catalog_items: True, has_web_only_items: False
# [TTS DEBUG] Products for voice:
# 1. LEGO Classic World Fun 10403 Building Kit (295 Piece) at $14.59 from our catalog, currently $34.99 at LEGO.com
# 2. LEGO City Dirt Road Pursuit 60172 Building Kit (297 Pieces) at $29.00 from our catalog, currently $25.85 at Walmart
# 3. LEGO Classic Creative Suitcase 10713 Building Kit (213 Pieces) at $19.78 from our catalog, currently $34.99 at LEGO.com
#
#   ROUGE-L:       0.1100
#   BLEU:          0.0100
#   Precision@5: 0.0000
#   Latency:       20933.8 ms
#   Cost:          (tokens not logged)
#
# --- [WARM] q7: Show me a non-stick frying pan under $40 that works on induction ---
#
# [ROUTER] Extracted intent: {'product_type': 'frying pan', 'budget': None, 'price_min': None, 'price_max': 40.0, 'category': None, 'eco_friendly': None, 'materials': None, 'age_range': None, 'brand': None}
#
# [SAFETY] Is safe: True
#
# [PLANNER] Plan: Search 2020 catalog, then verify current web prices for comparison
# [PLANNER] Tools: ['rag.search', 'web.search']
# [PLANNER] RAG params: {'query': 'non-stick frying pan', 'price_min': None, 'price_max': 40.0, 'category': None, 'eco_friendly': None, 'top_k': 5}
#
# [EXECUTOR] Calling rag.search...
# [EXECUTOR] RAG found: 0 products
#
# [EXECUTOR] Calling web.search (Google Shopping via MCP)...
# [EXECUTOR] Price filter: under $40.0
# [EXECUTOR] Searching alternatives: 'show me a non-stick frying pan under $40 that works on induction'...
# [EXECUTOR] Found 40 alternatives
# [EXECUTOR] Price filter: 40 → 40 results ($0-$40.0)
# [EXECUTOR] Total: 40 web results
#
# [RECONCILER] Starting reconciliation...
# [RECONCILER] RAG results: 0, Web results: 40
# [RECONCILER] No RAG results to reconcile
#
# [SYNTHESIZER] Generated answer with 0 unique citations
# [SYNTHESIZER] Total citations (with 7 unique web sources): 7
#
# [TTS DEBUG] has_catalog_items: False, has_web_only_items: True
# [TTS DEBUG] Products for voice:
# 1. Carote Nonstick Frying Pan 8" Skillet with Induction at $11.97 from Walmart
# 2. Anolon Achieve Hard Anodized Nonstick Frying Pan at $32.99 from Target
# 3. Thyme & Table Granite Collection Fry Pan at $24.86 from Walmart
#
#   ROUGE-L:       0.1194
#   BLEU:          0.0107
#   Precision@5: 0.0000
#   Latency:       10372.5 ms
#   Cost:          (tokens not logged)
#
# --- [WARM] q8: Skateboard under $60 ---
#
# [ROUTER] Extracted intent: {'product_type': 'skateboard', 'budget': None, 'price_min': None, 'price_max': 60.0, 'category': None, 'eco_friendly': None, 'materials': None, 'age_range': None, 'brand': None}
#
# [SAFETY] Is safe: True
#
# [PLANNER] Plan: Search 2020 catalog, then verify current web prices for comparison
# [PLANNER] Tools: ['rag.search', 'web.search']
# [PLANNER] RAG params: {'query': 'skateboard', 'price_min': None, 'price_max': 60.0, 'category': None, 'eco_friendly': None, 'top_k': 5}
#
# [EXECUTOR] Calling rag.search...
# [EXECUTOR] RAG found: 5 products
#
# [EXECUTOR] Calling web.search (Google Shopping via MCP)...
# [EXECUTOR] Price filter: under $60.0
# [EXECUTOR] Running 5 price checks in PARALLEL...
# [EXECUTOR] ✓ Punisher Skateboards Elephantasm Complet... → 37 results
# [EXECUTOR] ✓ Punisher Skateboards MAYAN Complete Skat... → 40 results
# [EXECUTOR] ✓ Ferrari Double Kick Skateboard... → 34 results
# [EXECUTOR] ✓ Quest QT-NSC44C The Super Cruiser The Or... → 7 results
# [EXECUTOR] ✓ Kryptonics Mini Cutaway Cruiser Skateboa... → 40 results
# [EXECUTOR] Parallel checks done in 3181ms
# [EXECUTOR] Searching alternatives: 'skateboard under $60'...
# [EXECUTOR] Found 40 alternatives
# [EXECUTOR] Price filter: 198 → 104 results ($0-$60.0)
# [EXECUTOR] Total: 104 web results
#
# [RECONCILER] Starting reconciliation...
# [RECONCILER] RAG results: 5, Web results: 104
# [RECONCILER] Matched 5 products
# [RECONCILER] Found 4 conflicts
# [RECONCILER] Created comparison table with 104 entries
# [RECONCILER] Example match: 'Ferrari Double Kick Skateboard...' <-> 'Ferrari Capa Dupla Skateboard...' (score: 0.671)
# [RECONCILER] Example conflict: Catalog shows $38.16, web shows $30.00 (21.4% difference)
#
# [SYNTHESIZER] Generated answer with 5 unique citations
# [SYNTHESIZER] Total citations (with 4 unique web sources): 9
#
# [TTS DEBUG] has_catalog_items: True, has_web_only_items: False
# [TTS DEBUG] Products for voice:
# 1. Ferrari Double Kick Skateboard at $38.16 from our catalog, currently $30.00 at eBay
# 2. Punisher Skateboards MAYAN Complete Skateboard with Convace Deck at $57.16 from our catalog, currently $59.99 at Punisher Skateboards
# 3. Punisher Skateboards Elephantasm Complete 31-Inch Skateboard All Maple at $39.99 from our catalog, currently $59.99 at Punisher Skateboards
#
#   ROUGE-L:       0.0667
#   BLEU:          0.0031
#   Precision@5: 0.0000
#   Latency:       17507.0 ms
#   Cost:          (tokens not logged)
#
# --- [WARM] q9: Party decorations under $100 ---
#
# [ROUTER] Extracted intent: {'product_type': 'party decorations', 'budget': None, 'price_min': None, 'price_max': 100.0, 'category': None, 'eco_friendly': None, 'materials': None, 'age_range': None, 'brand': None}
#
# [SAFETY] Is safe: True
#
# [PLANNER] Plan: Search 2020 catalog, then verify current web prices for comparison
# [PLANNER] Tools: ['rag.search', 'web.search']
# [PLANNER] RAG params: {'query': 'party decorations', 'price_min': None, 'price_max': 100.0, 'category': None, 'eco_friendly': None, 'top_k': 5}
#
# [EXECUTOR] Calling rag.search...
# [EXECUTOR] RAG found: 5 products
#
# [EXECUTOR] Calling web.search (Google Shopping via MCP)...
# [EXECUTOR] Price filter: under $100.0
# [EXECUTOR] Running 5 price checks in PARALLEL...
# [EXECUTOR] ⊘ Amscan 181576 Measures Party Needs, Mult... → 0 results (timeout or error)
# [EXECUTOR] ✓ Creative Converting 033023 Party Supplie... → 11 results
# [EXECUTOR] ✓ Amscan 241286 Party Décor, Multi Size, M... → 32 results
# [EXECUTOR] ✓ Amscan 241143 Party Décor, Assorted Size... → 5 results
# [EXECUTOR] ✓ LOAZRE Unicorn Backdrop Party Supplies D... → 40 results
# [EXECUTOR] Parallel checks done in 3139ms
# [EXECUTOR] Searching alternatives: 'party decorations under $100'...
# [EXECUTOR] Found 40 alternatives
# [EXECUTOR] Price filter: 128 → 121 results ($0-$100.0)
# [EXECUTOR] Total: 121 web results
#
# [RECONCILER] Starting reconciliation...
# [RECONCILER] RAG results: 5, Web results: 121
# [RECONCILER] Matched 2 products
# [RECONCILER] Found 2 conflicts
# [RECONCILER] Created comparison table with 125 entries
# [RECONCILER] Example match: 'Amscan 241286 Party Décor, Multi Size, Multicolor...' <-> 'Amscan Party Supplies, Multicolor...' (score: 0.596)
# [RECONCILER] Example conflict: Catalog shows $9.69, web shows $11.67 (20.4% difference)
#
# [SYNTHESIZER] Generated answer with 0 unique citations
# [SYNTHESIZER] Total citations (with 10 unique web sources): 10
#
# [TTS DEBUG] has_catalog_items: True, has_web_only_items: False
# [TTS DEBUG] Products for voice:
# 1. Amscan 241286 Party Décor, Multi Size, Multicolor at $9.69 from our catalog, currently $11.67 at eBay
# 2. Amscan 181576 Measures Party Needs, Multi Color at $8.20 from our catalog, currently $11.67 at eBay
# 3. Creative Converting 033023 Party Supplies, Black/Orange at $3.39 from our catalog
#
#   ROUGE-L:       0.1261
#   BLEU:          0.0101
#   Precision@5: 0.0000
#   Latency:       15691.0 ms
#   Cost:          (tokens not logged)
#
# --- [WARM] q10: I need an ergonomic office chair under $250 ---
#
# [ROUTER] Extracted intent: {'product_type': 'office chair', 'budget': 250, 'price_min': None, 'price_max': 250, 'category': None, 'eco_friendly': None, 'materials': None, 'age_range': None, 'brand': None}
#
# [SAFETY] Is safe: True
#
# [PLANNER] Plan: Search 2020 catalog, then verify current web prices for comparison
# [PLANNER] Tools: ['rag.search', 'web.search']
# [PLANNER] RAG params: {'query': 'ergonomic office chair', 'price_min': None, 'price_max': 250, 'category': 'office furniture', 'eco_friendly': None, 'top_k': 5}
#
# [EXECUTOR] Calling rag.search...
# [EXECUTOR] RAG found: 0 products
#
# [EXECUTOR] Calling web.search (Google Shopping via MCP)...
# [EXECUTOR] Price filter: under $250
# [EXECUTOR] Searching alternatives: 'i need an ergonomic office chair under $250'...
# [EXECUTOR] Found 40 alternatives
# [EXECUTOR] Price filter: 40 → 40 results ($0-$250)
# [EXECUTOR] Total: 40 web results
#
# [RECONCILER] Starting reconciliation...
# [RECONCILER] RAG results: 0, Web results: 40
# [RECONCILER] No RAG results to reconcile
#
# [SYNTHESIZER] Generated answer with 0 unique citations
# [SYNTHESIZER] Total citations (with 8 unique web sources): 8
#
# [TTS DEBUG] has_catalog_items: False, has_web_only_items: True
# [TTS DEBUG] Products for voice:
# 1. Wonder Comfort Ergonomic High-Back Mesh Reclining Home Office Desk Chair at $110.57 from Home Depot
# 2. Ergonomic Office Chair at $179.99 from Sunaofe
# 3. Union & Scale Flexfit Dexley Mesh Task Chair at $166.64 from Best Buy
#
#   ROUGE-L:       0.1266
#   BLEU:          0.0066
#   Precision@5: 0.0000
#   Latency:       12741.0 ms
#   Cost:          (tokens not logged)

# %% [markdown]
# ### First Time Evaluate

# %%
import pandas as pd

cold_df = pd.DataFrame(cold_summary["per_query"])
warm_df = pd.DataFrame(warm_summary["per_query"])

print("Cold cache – per query metrics")
display(cold_df[["id", "rouge_l", "bleu", "precision_at_k", "latency_ms", "cost"]])

print("Warm cache – per query metrics")
display(warm_df[["id", "rouge_l", "bleu", "precision_at_k", "latency_ms", "cost"]])

print("Aggregate metrics")
agg_df = pd.DataFrame([
    {
        "run_type": "COLD",
        "avg_rouge_l": cold_summary["avg_rouge_l"],
        "avg_bleu": cold_summary["avg_bleu"],
        "avg_precision_at_k": cold_summary["avg_precision_at_k"],
        "avg_latency_ms": cold_summary["avg_latency_ms"],
        "avg_cost": cold_summary["avg_cost"],
    },
    {
        "run_type": "WARM",
        "avg_rouge_l": warm_summary["avg_rouge_l"],
        "avg_bleu": warm_summary["avg_bleu"],
        "avg_precision_at_k": warm_summary["avg_precision_at_k"],
        "avg_latency_ms": warm_summary["avg_latency_ms"],
        "avg_cost": warm_summary["avg_cost"],
    }
])

display(agg_df)
# Out:
# Cold cache – per query metrics
#     id   rouge_l      bleu precision_at_k  latency_ms  cost
# 0   q1  0.162963  0.015190           None    16188.04  None
# 1   q2  0.111111  0.015165           None    20275.41  None
# 2   q3  0.149254  0.015016           None    61400.68  None
# 3   q4  0.139241  0.024793           None    19671.00  None
# 4   q5  0.146667  0.041380           None    23723.43  None
# 5   q6  0.088106  0.008722           None    54645.01  None
# 6   q7  0.129496  0.027822           None    16871.40  None
# 7   q8  0.093023  0.003318           None    17175.13  None
# 8   q9  0.095238  0.014567           None     2487.28  None
# 9  q10  0.108527  0.008012           None    51415.75  None
# Warm cache – per query metrics
#     id   rouge_l      bleu precision_at_k  latency_ms  cost
# 0   q1  0.135593  0.012438           None    23674.49  None
# 1   q2  0.101449  0.017041           None    12097.28  None
# 2   q3  0.138889  0.014307           None    18843.57  None
# 3   q4  0.131579  0.025960           None    59040.11  None
# 4   q5  0.140625  0.047407           None    12395.82  None
# 5   q6  0.090909  0.008561           None    21209.33  None
# 6   q7  0.192593  0.085209           None    12616.69  None
# 7   q8  0.076923  0.003264           None    14170.88  None
# 8   q9  0.095238  0.014567           None     2304.78  None
# 9  q10  0.116505  0.012198           None    16978.94  None
# Aggregate metrics
#   run_type  avg_rouge_l  avg_bleu avg_precision_at_k  avg_latency_ms avg_cost
# 0     COLD     0.122363  0.017398               None       28385.313     None
# 1     WARM     0.122030  0.024095               None       19333.189     None

# %% [markdown]
# ### Second Time Evaluate

# %%
import pandas as pd

cold_df = pd.DataFrame(cold_summary["per_query"])
warm_df = pd.DataFrame(warm_summary["per_query"])

print("Cold cache – per query metrics")
display(cold_df[["id", "rouge_l", "bleu", "precision_at_k", "latency_ms", "cost"]])

print("Warm cache – per query metrics")
display(warm_df[["id", "rouge_l", "bleu", "precision_at_k", "latency_ms", "cost"]])

print("Aggregate metrics")
agg_df = pd.DataFrame([
    {
        "run_type": "COLD",
        "avg_rouge_l": cold_summary["avg_rouge_l"],
        "avg_bleu": cold_summary["avg_bleu"],
        "avg_precision_at_k": cold_summary["avg_precision_at_k"],
        "avg_latency_ms": cold_summary["avg_latency_ms"],
        "avg_cost": cold_summary["avg_cost"],
    },
    {
        "run_type": "WARM",
        "avg_rouge_l": warm_summary["avg_rouge_l"],
        "avg_bleu": warm_summary["avg_bleu"],
        "avg_precision_at_k": warm_summary["avg_precision_at_k"],
        "avg_latency_ms": warm_summary["avg_latency_ms"],
        "avg_cost": warm_summary["avg_cost"],
    }
])

display(agg_df)
# Out:
# Cold cache – per query metrics
#     id   rouge_l      bleu  precision_at_k  latency_ms  cost
# 0   q1  0.135802  0.019546             0.0   159676.65  None
# 1   q2  0.137931  0.023563             0.0   126972.67  None
# 2   q3  0.215686  0.050967             0.0   196098.10  None
# 3   q4  0.136986  0.027331             0.0    39603.51  None
# 4   q5  0.147541  0.049479             0.0    22224.23  None
# 5   q6  0.081633  0.007654             0.0    59489.07  None
# 6   q7  0.094488  0.008502             0.0    29423.92  None
# 7   q8  0.081081  0.003999             0.0    21316.63  None
# 8   q9  0.095238  0.014567             NaN     2346.22  None
# 9  q10  0.081301  0.007625             0.0    21859.51  None
# Warm cache – per query metrics
#     id   rouge_l      bleu  precision_at_k  latency_ms  cost
# 0   q1  0.134021  0.010875             0.0    33838.47  None
# 1   q2  0.116667  0.015785             0.0    14334.66  None
# 2   q3  0.150943  0.014097             0.0    64595.53  None
# 3   q4  0.136054  0.028366             0.0    20620.19  None
# 4   q5  0.147541  0.049479             0.0    13060.31  None
# 5   q6  0.083682  0.008128             0.0    23745.73  None
# 6   q7  0.094488  0.008502             0.0    14642.35  None
# 7   q8  0.075188  0.003160             0.0    15264.90  None
# 8   q9  0.095238  0.014567             NaN     3416.14  None
# 9  q10  0.086957  0.007632             0.0    13121.72  None
# Aggregate metrics
#   run_type  avg_rouge_l  avg_bleu  avg_precision_at_k  avg_latency_ms avg_cost
# 0     COLD     0.120769  0.021323                 0.0       67901.051     None
# 1     WARM     0.112078  0.016059                 0.0       21664.000     None

# %% [markdown]
# ### Third Time Evaluate

# %%
import pandas as pd

cold_df = pd.DataFrame(cold_summary["per_query"])
warm_df = pd.DataFrame(warm_summary["per_query"])

print("Cold cache – per query metrics")
display(cold_df[["id", "rouge_l", "bleu", "precision_at_k", "latency_ms", "cost"]])

print("Warm cache – per query metrics")
display(warm_df[["id", "rouge_l", "bleu", "precision_at_k", "latency_ms", "cost"]])

print("Aggregate metrics")
agg_df = pd.DataFrame([
    {
        "run_type": "COLD",
        "avg_rouge_l": cold_summary["avg_rouge_l"],
        "avg_bleu": cold_summary["avg_bleu"],
        "avg_precision_at_k": cold_summary["avg_precision_at_k"],
        "avg_latency_ms": cold_summary["avg_latency_ms"],
        "avg_cost": cold_summary["avg_cost"],
    },
    {
        "run_type": "WARM",
        "avg_rouge_l": warm_summary["avg_rouge_l"],
        "avg_bleu": warm_summary["avg_bleu"],
        "avg_precision_at_k": warm_summary["avg_precision_at_k"],
        "avg_latency_ms": warm_summary["avg_latency_ms"],
        "avg_cost": warm_summary["avg_cost"],
    }
])

display(agg_df)
# Out:
# Cold cache – per query metrics
#     id   rouge_l      bleu  precision_at_k  latency_ms  cost
# 0   q1  0.157895  0.013975             0.0    16411.29  None
# 1   q2  0.115942  0.017041             0.0    20388.39  None
# 2   q3  0.155440  0.014974             0.0    58690.34  None
# 3   q4  0.139241  0.026674             0.0    24332.43  None
# 4   q5  0.052045  0.004070             0.0    55529.62  None
# 5   q6  0.148649  0.013196             0.0    57549.75  None
# 6   q7  0.123077  0.011182             0.0    15779.50  None
# 7   q8  0.052402  0.002779             0.0    50256.91  None
# 8   q9  0.070312  0.004676             0.0    50038.29  None
# 9  q10  0.094595  0.009730             0.0    40554.23  None
# Warm cache – per query metrics
#     id   rouge_l      bleu  precision_at_k  latency_ms  cost
# 0   q1  0.129730  0.011578             0.0    24249.62  None
# 1   q2  0.137931  0.023563             0.0    10441.25  None
# 2   q3  0.180791  0.015565             0.0    22186.45  None
# 3   q4  0.128205  0.025363             0.0    15344.45  None
# 4   q5  0.059041  0.004573             0.0    26957.99  None
# 5   q6  0.110000  0.009955             0.0    20933.84  None
# 6   q7  0.119403  0.010716             0.0    10372.55  None
# 7   q8  0.066667  0.003129             0.0    17507.04  None
# 8   q9  0.126126  0.010078             0.0    15691.01  None
# 9  q10  0.126582  0.006642             0.0    12741.05  None
# Aggregate metrics
#   run_type  avg_rouge_l  avg_bleu  avg_precision_at_k  avg_latency_ms avg_cost
# 0     COLD     0.110960  0.011830                 0.0       38953.075     None
# 1     WARM     0.118448  0.012116                 0.0       17642.525     None
